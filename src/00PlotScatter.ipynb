# %% [markdown]
# # Sec 1. Useful Definitions

# %%
from stdA import *
# %pylab inline
def omwtex(om, w, fmt='%.2f'):
    return '$\\Omega_m='+fmt%om+',\\ w='+fmt%w+'$'
from matplotlib.font_manager import FontProperties
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['product', 'random', 'transpose', 'copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# # Sec 2. Plottings

# %%
for zstr in ['0', '0.5', '1', '1.5', '2']:
    z=float(zstr)
    stretch = comov_r(0.05,-1.5,0.7,z+0.0001) / comov_r(0.26,-1,0.7,z+0.0001)
    print stretch
# Out:
# 1.00005137535
# 1.25649648829
# 1.47280317691
# 1.62180241059
# 1.71741906054

# %%
zstrs =  ['0', '0.5', '1', '1.5', '2']
numz = len(zstrs)

yrat = 0.6
psize = 0.5

fig = plt.figure(figsize=(8*2,8*yrat*numz))
xymin, xymax = 0, 220
#xticks0 = [50,100,150,200,]
xticks0 = [40,80,120,160,200]

om, w = 0.05, -1.5

iz = 0
for zstr in zstrs:
    iz+=1
    ax1, ax2 = fig.add_subplot(numz,2,iz*2-1), fig.add_subplot(numz,2,iz*2)

    if iz==1:
        ax1.set_title('$\\rm Correct\\ Cosmology$', fontsize=26)
        ax2.set_title(omwtex(om,w), fontsize=26)
    
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    
    ax1.set_xticks(xticks0)
    ax1.set_yticks(xticks0)
    
    z=float(zstr)
    stretch = comov_r(om,w,0.7,z+0.0001) / comov_r(0.26,-1,0.7,z+0.0001)
    xticks1 = [x*stretch for x in xticks0]
    #nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    #data = np.loadtxt(nowfile)
    #X, Y = XYfromdata(data)
    #X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    
    ax2.set_xticks(xticks1)
    ax2.set_yticks(xticks1)
    
    nowstr=omwtex(om,w)
    nowstr=nowstr[1:len(nowstr)]
    ax1.text(0.1, 0.9, 'z='+zstr, transform = ax1.transAxes, color='red', fontsize=20,
            fontproperties = FontProperties(weight='bold', ))
    ax2.text(0.1, 0.9, 'z='+zstr, transform = ax2.transAxes, color='red', fontsize=20,
            fontproperties = matplotlib.font_manager.FontProperties(weight='bold', ))
    
    for ax in [ax1, ax2]:
        ax.set_xlim(xymin, xymax)
        ax.set_ylim(xymin, xymax*yrat)
        ax.grid(lw=1,ls='-',c='g')
    
    tickft = 12
    ax1.set_xticklabels([str(x) for x in ax1.get_xticks()], fontsize=tickft)
    ax1.set_yticklabels([str(x) for x in ax1.get_yticks()], fontsize=tickft)
    if iz ==1:
        ax2.set_xticklabels(['%.0f'%x for x in ax2.get_xticks()], fontsize=tickft)
        ax2.set_yticklabels(['%.0f'%x for x in ax2.get_yticks()], fontsize=tickft)
    else:
        ax2.set_xticklabels([str(float('%.1f'%x)) for x in ax2.get_xticks()], fontsize=tickft)
        ax2.set_yticklabels([str(float('%.1f'%x)) for x in ax2.get_yticks()], fontsize=tickft)
        
    
        
    if iz == numz:
        ax1.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
        ax2.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    ax1.set_ylabel('$y\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
plt.show()
fig.savefig('../draft/fig8.eps', format='eps')

# %%
rat = 14/18.0
print 9*2*rat, 9*yrat*numz*rat
# Out:
# 14.0 17.5

# %%
zstrs =  [ '0.5', '1', '1.5', '2']
numz = len(zstrs)

yrat = 0.5
psize = 0.8
pc='k'

fig = plt.figure(figsize=(9*2,9*yrat*numz))
xymin, xymax = 0, 260
#xticks0 = [50,100,150,200,]
#xticks0 = [40,80,120,160,200,240]
xticks0 = [50,100,150,200,250]

om, w = 0.05, -1.5
noplot = False

iz = 0
for zstr in zstrs:
    iz+=1
    ax1, ax2 = fig.add_subplot(numz,2,iz*2-1), fig.add_subplot(numz,2,iz*2)
    
    if iz==1:
        ax1.set_title('$\\rm Correct\\ Cosmology$', fontsize=26)
        ax2.set_title(omwtex(om,w), fontsize=26)
        
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    if not noplot:
        data = np.loadtxt(nowfile)
        X, Y = XYfromdata(data)
        X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax*yrat, onlyreturnvalue=True)
        ax1.scatter(X1,Y1, linewidths=0, c=pc, s=psize)
    ax1.set_xticks(xticks0)
    ax1.set_yticks(xticks0)
    
    z=float(zstr)
    stretch = comov_r(om,w,0.7,z+0.0001) / comov_r(0.26,-1,0.7,z+0.0001)
    xticks1 = [x*stretch for x in xticks0]
    #nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    #data = np.loadtxt(nowfile)
    #X, Y = XYfromdata(data)
    #X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    if not noplot:
        X1 = [x1*stretch for x1 in X1]
        Y1 = [y1*stretch for y1 in Y1]
        ax2.scatter(X1,Y1, linewidths=0, c=pc, s=psize*stretch)
    ax2.set_xticks(xticks1)
    ax2.set_yticks(xticks1)
    
    nowstr=omwtex(om,w)
    nowstr=nowstr[1:len(nowstr)]
    axtext = 'z=%.1f'%float(zstr)
    ax1.text(0.07, 0.85, axtext, transform = ax1.transAxes, color='red', fontsize=20,
            fontproperties = FontProperties(weight='bold', ))
    #ax2.text(0.1, 0.9, 'z='+zstr+' ($\\bf \\Omega_m$ = %.2f'%om+', w = %.2f'%w+')', transform = ax2.transAxes, color='red', fontsize=20,
    
    if iz > 1:
        axtext += ' (x%.3f'%stretch+')'
    ax2.text(0.07, 0.85, axtext, transform = ax2.transAxes, color='red', fontsize=20,
            fontproperties = matplotlib.font_manager.FontProperties(weight='bold', ))
    
    for ax in [ax1, ax2]:
        ax.set_xlim(xymin, xymax)
        ax.set_ylim(xymin, xymax*yrat)
    
        ax.grid(lw=2,ls=':',c='r')
    
    tickft = 12
    ax1.set_xticklabels([str(x) for x in ax1.get_xticks()], fontsize=tickft)
    ax1.set_yticklabels([str(x) for x in ax1.get_yticks()], fontsize=tickft)
    if iz ==1:
        ax2.set_xticklabels(['%.0f'%x for x in ax2.get_xticks()], fontsize=tickft)
        ax2.set_yticklabels(['%.0f'%x for x in ax2.get_yticks()], fontsize=tickft)
    else:
        ax2.set_xticklabels([str(float('%.1f'%x)) for x in ax2.get_xticks()], fontsize=tickft)
        ax2.set_yticklabels([str(float('%.1f'%x)) for x in ax2.get_yticks()], fontsize=tickft)
    
    if iz == numz:
        ax1.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
        ax2.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    ax1.set_ylabel('$y\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
fig.tight_layout()
plt.show()
fig.savefig('../draft/fig2.eps', format='eps')
fig.savefig('../draft/fig2.pdf', format='pdf')
fig.savefig('../draft/fig2.png', format='png')

# %%
if True:
    ommin,ommax,numom, wmin,wmax,numw = 0.2,0.31,51,-1.15,-0.85,76
    omwlist = [[om,w]]

do_calc = False

ncol = len(omwlist)
nrow=4

fig = plt.figure(figsize=(4*ncol,6*nrow))

for i1i2 in [[6,40]]:
 for sfact in [1]:
  for zstrs in [['0', '0.5', '1', '1.5', '2']]:
    
    i1, i2 = i1i2
    om_dft, w_dft = [0.26,-1]
    Scanname = 'Plot_omw'

    ## 2. Settings for plots
    make_plot = True
    savefig=True

    ## 3. Error bar settings
    use_whole_snapshot_erbar = True

    ## 4. Normalization
    def norm_SkipLast(X):
        return normto1(X)[0:len(X)-1]
    normfun = norm_SkipLast

    scanstr  = Scanname+\
        '__zstrs_'+array_to_str(zstrs,'_')+'_sfact'+str(sfact)+'_s'+str(i1-1)+'to'+str(i2)
    if use_whole_snapshot_erbar:
        scanstr+= '_WholeSnapShot'
    else:
        scanstr+= '_SingleSubSlice'
    print '####################################'
    print scanstr
    #continue
    #print omlist, wlist
    minimal_rescale_outflow_thredshold = i2 / (50+0.0)
    print 'Rescale shall  >', minimal_rescale_outflow_thredshold, ' to avoid outflow.'

    if True:
        ### 1. Storage Structures 
        ## 1.1 Covariance for delta Y1/2/3
        covmats_Delta_Y1 = []
        covmats_Delta_Y2 = []
        covmats_Delta_Y3 = []
        ## 1.2 Error bar (diagnol of sqrt of covmat)
        Delta_Yer1s = []
        Delta_Yer2s = []
        Delta_Yer3s = []
        ## 1.3 Systematic correction
        Delta_Y1_syss = []
        Delta_Y2_syss = []
        Delta_Y3_syss = []
        iomw = 0
        ### 2. Loop of rescales
        chisq_dict = {}

        iomw = -1
        for omw in [[om_dft, w_dft]]+omwlist:
            iomw += 1
            om,w = omw
            rescales = [DA(om,w,0.6,float(zz)+0.00001)/DA(om_dft,w_dft,0.6,float(zz)+0.00001) for zz in zstrs]
            chisq_dict[omwstr(om,w)] = []
            iz = 0
            if iomw >0:
                #ax1a, ax2a, ax3b = fig.add_subplot(nrow,3,(iomw-1)*3+1), \
                #    fig.add_subplot(nrow,3,(iomw-1)*3+2), \
                #    fig.add_subplot(nrow,3,(iomw-1)*3+3)
                ax1a, ax2a, ax3b = fig.add_subplot(nrow,ncol,iomw), \
                    fig.add_subplot(nrow,ncol,ncol+iomw), \
                    fig.add_subplot(nrow,ncol,ncol*2+iomw)
            ## 2.1 Loop of redshifts
            chisq_Y3_corred_all = 0
            for nowzstr in zstrs:
                # 2.1.1 Preparations: Name of files; value of rescale; read-in; 
                nowfiles = sumlist([[nowdir+'J08.dat.z_'+nowzstr+'.mge3.000e11.slice'+\
                            str(islice)+'.'+str(isubslice)+'.rmax50.50rbins.2pcf' \
                            for isubslice in range(1,5)] for islice in range(1,31)])
                rescale = rescales[iz]
                nowdatas = [np.loadtxt(nowfile, skiprows=1) for nowfile in nowfiles]
                num_mock = len(nowdatas)
                XiLSs = [[nowdatas[ii1][ii2][7] for ii2 in range(len(nowdatas[ii1]))] for ii1 in range(len(nowdatas))]

                # 2.1.2 Averaged result
                nowdata = get_avg_array2D(nowdatas)
                R1, R2, DD, DR, RR, XiN, XiD, XiLS = Xsfromdata(nowdata, range(8))
                Rmid_orig = [((R1[row]**3.0+R2[row]**3.0)*0.5)**(1.0/3.0) for row in range(len(R1))]
                Rmid = [rr*rescale for rr in Rmid_orig]

                # 2.1.3 Main body of computation
                Y1 = XmultY(Rmid, XiLS,a=sfact);
                Y2 = normfun(Y1)
                X3 = Rmid_orig[i1-1:i2]; ### Values of r at which we care about
                Y3 = normfun(LinearInterpolation_IOA(Rmid, Y1, X3))

                Y1s = [XmultY(Rmid, XX,a=sfact) for XX in XiLSs]
                Y2s = [normfun(XX) for XX in Y1s]
                Y3s = [normfun(LinearInterpolation_IOA(Rmid, XX, X3)) for XX in Y1s]
                nowcovmat_Y1 = get_covmat(transpose(Y1s))
                nowcovmat_Y2 = get_covmat(transpose(Y2s))
                nowcovmat_Y3 = get_covmat(transpose(Y3s))
                Yer1 = [(nowcovmat_Y1[ii][ii])**0.5  for ii in range(len(nowcovmat_Y1))]
                Yer2 = [(nowcovmat_Y2[ii][ii])**0.5  for ii in range(len(nowcovmat_Y2))]
                Yer3 = [(nowcovmat_Y3[ii][ii])**0.5  for ii in range(len(nowcovmat_Y3))]
                if use_whole_snapshot_erbar: 
                    ernormfact = 1.0/(num_mock+0.0-1)**0.5
                    Yer1 = [xx*ernormfact  for xx in Yer1]
                    Yer2 = [xx*ernormfact  for xx in Yer2]
                    Yer3 = [xx*ernormfact  for xx in Yer3]

                if iz == 0:
                    Y1ref = [xx for xx in Y1]; 
                    Y2ref = [xx for xx in Y2]; 
                    Y3ref = [xx for xx in Y3];
                    Y1refs = [[xxx for xxx in xx] for xx in Y1s]
                    Y2refs = [[xxx for xxx in xx] for xx in Y2s]
                    Y3refs = [[xxx for xxx in xx] for xx in Y3s]

                    if iomw == 0: # Add to storage
                        covmats_Delta_Y1.append(0);covmats_Delta_Y2.append(0);covmats_Delta_Y3.append(0)
                        Delta_Yer1s.append(0);Delta_Yer2s.append(0);Delta_Yer3s.append(0)
                        Delta_Y1_syss.append(0);Delta_Y2_syss.append(0);Delta_Y3_syss.append(0);
                else:
                    Delta_Y1 = get_diffarray(Y1ref,Y1);
                    Delta_Y2 = get_diffarray(Y2ref,Y2);
                    Delta_Y3 = get_diffarray(Y3ref,Y3);
                    if iomw == 0:
                        Delta_Y1_sys = [xx for xx in Delta_Y1];
                        Delta_Y2_sys = [xx for xx in Delta_Y2];
                        Delta_Y3_sys = [xx for xx in Delta_Y3];
                        Delta_Y1_syss.append([xx for xx in Delta_Y1_sys]);
                        Delta_Y2_syss.append([xx for xx in Delta_Y2_sys]);
                        Delta_Y3_syss.append([xx for xx in Delta_Y3_sys]);

                        Delta_Y1s = [get_diffarray(Y1refs[row-delta_imock],Y1s[row]) for row in range(len(Y1s))]
                        Delta_Y2s = [get_diffarray(Y2refs[row-delta_imock],Y2s[row]) for row in range(len(Y2s))]
                        Delta_Y3s = [get_diffarray(Y3refs[row-delta_imock],Y3s[row]) for row in range(len(Y3s))]
                        nowcovmat_Delta_Y1 = get_covmat(transpose(Delta_Y1s))
                        nowcovmat_Delta_Y2 = get_covmat(transpose(Delta_Y2s))
                        nowcovmat_Delta_Y3 = get_covmat(transpose(Delta_Y3s))
                        covmats_Delta_Y1.append([[xxx for xxx in xx] for xx in nowcovmat_Delta_Y1])
                        covmats_Delta_Y2.append([[xxx for xxx in xx] for xx in nowcovmat_Delta_Y2])
                        covmats_Delta_Y3.append([[xxx for xxx in xx] for xx in nowcovmat_Delta_Y3])

                        Delta_Yer1 = [(nowcovmat_Delta_Y1[ii][ii])**0.5  for ii in range(len(nowcovmat_Delta_Y1))]
                        Delta_Yer2 = [(nowcovmat_Delta_Y2[ii][ii])**0.5  for ii in range(len(nowcovmat_Delta_Y2))]
                        Delta_Yer3 = [(nowcovmat_Delta_Y3[ii][ii])**0.5  for ii in range(len(nowcovmat_Delta_Y3))]
                        if use_whole_snapshot_erbar: 
                            ernormfact = 1.0/(num_mock+0.0-1)**0.5
                            Delta_Yer1 = [xx*ernormfact  for xx in Delta_Yer1]
                            Delta_Yer2 = [xx*ernormfact  for xx in Delta_Yer2]
                            Delta_Yer3 = [xx*ernormfact  for xx in Delta_Yer3]
                        Delta_Yer1s.append([xx for xx in Delta_Yer1])
                        Delta_Yer2s.append([xx for xx in Delta_Yer2])
                        Delta_Yer3s.append([xx for xx in Delta_Yer3])

                    chisq_Y1_uncor = chisq_like_cov_xbar(Delta_Y1, covmats_Delta_Y1[iz])[0]
                    chisq_Y2_uncor = chisq_like_cov_xbar(Delta_Y2, covmats_Delta_Y2[iz])[0]
                    chisq_Y3_uncor = chisq_like_cov_xbar(Delta_Y3, covmats_Delta_Y3[iz])[0]
                    chisq_Y1_corred = chisq_like_cov_xbar(get_diffarray(Delta_Y1, Delta_Y1_syss[iz]), covmats_Delta_Y1[iz])[0]
                    chisq_Y2_corred = chisq_like_cov_xbar(get_diffarray(Delta_Y2, Delta_Y2_syss[iz]), covmats_Delta_Y2[iz])[0]
                    chisq_Y3_corred = chisq_like_cov_xbar(get_diffarray(Delta_Y3, Delta_Y3_syss[iz]), covmats_Delta_Y3[iz])[0]
                    if use_whole_snapshot_erbar: 
                        ernormfact = 1.0/(num_mock+0.0-1)**0.5
                        chisq_Y1_uncor /= (ernormfact**2.0); chisq_Y2_uncor /= (ernormfact**2.0); 
                        chisq_Y3_uncor /= (ernormfact**2.0);
                        chisq_Y1_corred /= (ernormfact**2.0); chisq_Y2_corred /= (ernormfact**2.0); 
                        chisq_Y3_corred /= (ernormfact**2.0);
                    chisq_dict[omwstr(om,w)].append([chisq_Y1_uncor,chisq_Y1_corred,
                                                         chisq_Y2_uncor,chisq_Y2_corred,
                                                         chisq_Y3_uncor,chisq_Y3_corred,])
                    chisq_Y3_corred_all += chisq_Y3_corred
                nowlab='$z=%.2f'%float(nowzstr)+'$'
                if iomw >0:
                    ax1a.errorbar(Rmid, Y1, Yer1, label = nowlab, c=PCA2[iz], lw=2)
                    
                    ax2a.errorbar(Rmid[0:len(Y2)], Y2, Yer2, label = nowlab, c=PCA2[iz], lw=2)
                    if iz != 0:
                        sig = np.sqrt(chisq_Y3_corred)
                        ax3b.errorbar(X3[0:len(Y3)],   Delta_Y3, Delta_Yer3, 
                                      #label = 'z='+nowzstr+',rescale=%.2f'%rescale+\
                                      #'\n$\\chi^2=%.2f'%chisq_Y3_uncor+';\\ %.2f'%chisq_Y3_corred+'$', 
                                      #label = nowlab+' $,\\ \\Delta \\chi^2\\ =\\ %5.1f'%(chisq_Y3_corred)+'$',
                                      label = nowlab+'$:\\ \\Delta \\chi^2='+str(int(chisq_Y3_corred))+'\\ (%.1f'%sig+'\\sigma) $',
                                      c=PCA2[iz], lw=2)
                iz += 1
                
            if iomw == 0:
                continue

            ax2a.plot([0,50],[1,1],lw=2,ls='--',c='k')
            ax3b.plot([0,50],[0,0],lw=2,ls='--',c='k')
            
            ## grid, legend, xlim
            for ax in [ax1a,ax2a,ax3b]:
                ax.grid()
                ax.legend(loc='upper right',frameon=False,fontsize=17)
                ax.set_xlim(i1-1+0.5,i2-0.5)
            ax3b.legend(loc='upper right',frameon=False,fontsize=14)
            #ax1a.legend(loc='upper right')
            
            ## text
            ax1a.text(0.1,0.1,omwtex(om,w), transform=ax1a.transAxes,fontsize=18)
            sig = np.sqrt(chisq_Y3_corred_all)
            ax3b.text(0.1,0.03,'$\\rm \\Delta \\chi^2_{\\rm total}='+str(int(chisq_Y3_corred_all))+'\\ (%.1f'%sig+'\\sigma) $', 
                      transform=ax3b.transAxes,fontsize=18)
            
            
            ### ylabel, yticks
            if iomw == 1:
                ax1a.set_ylabel('$r \\xi $', fontsize=26)
                ax2a.set_ylabel('$\\hat {r \\xi}$', fontsize=26)
                ax3b.set_ylabel('$\\hat {r \\xi}(z)\\ -\\ \\hat {r \\xi}(z=0)$', fontsize=26)
            else:
                for ax in [ax1a,ax2a,ax3b]:
                    for ytl in ax.get_yticklabels():
                        ytl.set_visible(False)
            
            ### xlabel, xticks
            for ax in [ax1a,ax2a]:
                for xtl in ax.get_xticklabels():
                    xtl.set_visible(False)
                ax.set_xlabel('x', visible=False)
            ax3b.set_xlabel('$r\\ [h^{-1}\\rm \\ Mpc]$', fontsize=26)
            
            ## ylim
            ax1a.set_ylim(0.21,1.6)
            ax2a.set_ylim(0.41,1.59)
            ax3b.set_ylim(-0.11,0.16)
 
ax3b.legend(loc='upper left',frameon=False,fontsize=12)
fig.tight_layout(w_pad=0, h_pad=-5.8)
fig.savefig('../draft/fig3.eps', format='eps')
plt.show()

# %% [markdown]
# ### Plot in the correct cosmology

# %%
xymin, xymax = 0, 200
for zstr in ['0', '0.5', '1', '1.5', '2']:
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    data = np.loadtxt(nowfile)
    X, Y = XYfromdata(data)
    X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    fig, ax = figax(8,8)
    ax.scatter(X1,Y1, linewidths=0, c='k', s=1.5)
    ax.set_xlim(xymin, xymax)
    ax.set_ylim(xymin, xymax)
    ax.text(0.1, 0.9, 'z='+zstr+'', transform = ax.transAxes, color='red', fontsize=20,
            fontproperties = FontProperties(weight='bold', ))
    ax.grid(lw=2)
    ax.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    ax.set_ylabel('$y\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    plt.show()
    fig.savefig('../draft/fig8_'+zstr+'.eps', format='eps')
    print zstr, len(data)
# Out:
# 0 944223
# 0.5 834610
# 1 720106
# 1.5 620698
# 2 459237

# %% [markdown]
# ### Plot in the wrong cosmology

# %%
om, w = 0.1, -1

xticks0 = [20,40,60,80,100,120,140,160,180,200]
xymin, xymax = 0, 200
for zstr in ['0', '0.5', '1', '1.5', '2']:
    z=float(zstr)
    stretch = comov_r(om,w,0.7,z+0.0001) / comov_r(0.26,-1,0.7,z+0.0001)
    xticks1 = [x*stretch for x in xticks0]
    #xticks1 = 
    #print stretch
    #continue
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    data = np.loadtxt(nowfile)
    X, Y = XYfromdata(data)
    X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    X1 = [x1*stretch for x1 in X1]
    Y1 = [y1*stretch for y1 in Y1]
    fig, ax = figax(8,4.2)
    ax.scatter(X1,Y1, linewidths=0, c='k', s=1.5*stretch)
    ax.set_xticks(xticks1)
    ax.set_yticks(xticks1)
    ax.set_xlim(xymin, xymax)
    ax.set_ylim(xymin, xymax)
    nowstr=omwtex(om,w)
    nowstr=nowstr[1:len(nowstr)]
    ax.text(0.1, 0.9, 'z='+zstr+' ($\\bf \\Omega_m$ = 0.10, w = -1.0)', transform = ax.transAxes, color='red', fontsize=20,
            fontproperties = matplotlib.font_manager.FontProperties(weight='bold', ))
    ax.grid(lw=2)
    ax.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    ax.set_ylabel('$y\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    plt.show()
    fig.savefig('../draft/fig8_wrongcos_'+zstr+'.eps', format='eps')
    print zstr, len(data)
# Out:
# 0 944223
# 0.5 834610
# 1 720106
# 1.5 620698
# 2 459237

# %%
xymin, xymax = 0, 200
for zstr in ['0', '0.5', '1', '1.5', '2']:
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    data = np.loadtxt(nowfile)
    X, Y = XYfromdata(data)
    X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    fig, ax = figax(8,8)
    ax.scatter(X1,Y1, linewidths=0, c='b', s=1.5)
    ax.set_xlim(xymin, xymax)
    ax.set_ylim(xymin, xymax)
    ax.text(0.1, 0.9, '$z='+zstr+'$', transform = ax.transAxes, color='k', fontsize=24)
    ax.grid(lw=2)
    ax.set_xlabel('$x\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    ax.set_ylabel('$y\\ [h^{-1} \\ \\rm Mpc]$', fontsize=18)
    plt.show()
    fig.savefig('../fig8_'+zstr+'.eps', format='eps')
    print zstr, len(data)
# Out:
# 0 944223
# 0.5 834610
# 1 720106
# 1.5 620698
# 2 459237

# %%
xymin, xymax = 170, 200
for zstr in ['0', '0.5', '1', '1.5', '2']:
    nowfile = '../J08.dat.z_'+zstr+'.mge3.000e11.slice1.1.part'
    data = np.loadtxt(nowfile)
    X, Y = XYfromdata(data)
    X1, Y1 = XYinrange(X, Y, xymin, xymax, xymin, xymax, onlyreturnvalue=True)
    fig, ax = figax(10,10.5)
    ax.scatter(X1,Y1, linewidths=0, c='k', s=10)
    ax.set_xlim(xymin, xymax)
    ax.set_ylim(xymin, xymax)
    ax.text(0.1, 0.9, zstr, transform = ax.transAxes, fontsize=18)
    ax.grid()
    plt.show()
    print zstr, len(data)
# Out:
# 0 944223
# 0.5 834610
# 1 720106
# 1.5 620698
# 2 459237
